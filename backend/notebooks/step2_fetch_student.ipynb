# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="La_12122005",
    database="mydb"
)

print("Connected successfully")
# Out:
# Connected successfully

# %%
import mysql.connector

def fetch_student(reg_no):
    conn = mysql.connector.connect(
        host="localhost",
        user="root",
        password="La_12122005",
        database="mydb"
    )
    
    cursor = conn.cursor(dictionary=True)
    query = "SELECT reg_no, name, department, section FROM students WHERE reg_no = %s"
    cursor.execute(query, (reg_no,))
    
    student = cursor.fetchone()
    
    cursor.close()
    conn.close()
    
    return student

# Test
print(fetch_student("RA2311026050118"))
# Out:
# {'reg_no': 'RA2311026050118', 'name': 'LALIT ADITYA S', 'department': 'AIML', 'section': 'A'}
